# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_json("counties.json")

# %%
df
# Out:
#                name         capital  code  \
# 0           Baringo        Kabarnet    30
# 1             Bomet           Bomet    36
# 2           Bungoma         Bungoma    39
# 3             Busia           Busia    40
# 4   Elgeyo-Marakwet            Iten    28
# 5              Embu            Embu    14
# 6           Garissa         Garissa     7
# 7          Homa Bay        Homa Bay    43
# 8            Isiolo          Isiolo    11
# 9           Kajiado             NaN    34
# 10         Kakamega        Kakamega    37
# 11          Kericho         Kericho    35
# 12           Kiambu          Kiambu    22
# 13           Kilifi          Kilifi     3
# 14        Kirinyaga  Kerugoya/Kutus    20
# 15            Kisii           Kisii    45
# 16           Kisumu          Kisumu    42
# 17            Kitui           Kitui    15
# 18            Kwale           Kwale     2
# 19         Laikipia        Rumuruti    31
# 20             Lamu            Lamu     5
# ...

# %%
df.columns
# Out:
# Index(['name', 'capital', 'code', 'sub_counties'], dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                name         capital  code  \
# 0           Baringo        Kabarnet    30
# 1             Bomet           Bomet    36
# 2           Bungoma         Bungoma    39
# 3             Busia           Busia    40
# 4   Elgeyo-Marakwet            Iten    28
# 5              Embu            Embu    14
# 6           Garissa         Garissa     7
# 7          Homa Bay        Homa Bay    43
# 8            Isiolo          Isiolo    11
# 9           Kajiado             NaN    34
# 10         Kakamega        Kakamega    37
# 11          Kericho         Kericho    35
# 12           Kiambu          Kiambu    22
# 13           Kilifi          Kilifi     3
# 14        Kirinyaga  Kerugoya/Kutus    20
# 15            Kisii           Kisii    45
# 16           Kisumu          Kisumu    42
# 17            Kitui           Kitui    15
# 18            Kwale           Kwale     2
# 19         Laikipia        Rumuruti    31
# ...

# %%
df.sub_counties.value_counts().sum()
# Out:
# 47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          47 non-null     object
#  1   capital       46 non-null     object
#  2   code          47 non-null     int64
#  3   sub_counties  47 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.6+ KB
