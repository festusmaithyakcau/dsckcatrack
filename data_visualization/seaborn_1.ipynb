# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#impoting essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#loading dataset
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
 # first five rows of dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
 # last five rows of dataset
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %% [markdown]
# Swarm Plots

# %%
# use swarmplot to visualize tip observations and amounts
# by day of the week
sns.swarmplot(x="day", y="tip", data=df)
sns.set_style("whitegrid")
plt.show()

# %%
# visualize tip observations
sns.swarmplot(x=df["tip"])
sns.set_style("darkgrid")
plt.show()

# %%
# color points by category
# create customized palette
gender_palette = ["#A833FF", "#FFAF33"]
sns.swarmplot(x="day", y="tip", hue="sex", palette=gender_palette, data=df)
plt.show()

# %%
 # control plot order on x-axis
sns.swarmplot(x="smoker", y="total_bill", data=df,  hue="sex",palette="husl", order=["Yes", "No"])
plt.show()

# %% [markdown]
# Violin Plots

# %%
# plot tips
sns.violinplot(x = df["tip"], color="gold")
plt.show()

# %%
# draw plot based on variable
sns.violinplot(x ="sex",y ="total_bill",data=df)
plt.show()

# %%
# Split drawings to compare with hue/legend variables
sns.violinplot(x = "time",y ="tip",data=df, hue ="sex",palette ="dark",split = True)
plt.legend()
plt.show()

# %% [markdown]
# Facet Grids

# %%
# draw facet grid based on tip variable
fg = sns.FacetGrid(df,col = "time",row = "sex")

fg = fg.map(plt.hist,"tip", color ="tomato")

# %%
# we can also change the type of plot and the colors around the points
fg = sns.FacetGrid(df, col="time", row="sex")
fg = fg.map(plt.scatter, "total_bill", "tip", color="floralwhite", edgecolor="hotpink")

# %%
# plot by category
x = sns.FacetGrid(df, col="time", hue="sex")
x = x.map(plt.scatter,"total_bill","tip")
x =x.add_legend()

# %% [markdown]
# Heat Maps

# %%
# create random data
uniform_data = np.random.rand(5, 3) # five rows, 3 columns
print(uniform_data)
# Out:
# [[0.71261987 0.50319657 0.79823512]
#  [0.23959264 0.4692803  0.83924854]
#  [0.87884736 0.08978877 0.07803096]
#  [0.92202343 0.21111784 0.88911586]
#  [0.15640073 0.9152646  0.70610343]]

# %%
sns.heatmap(uniform_data)
plt.show()

# %%
# load in flights dataset
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
flights = flights.pivot("month", "year", "passengers")
# draw border
x = sns.heatmap(flights, linewidths=0.3)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14048\1327491859.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot("month", "year", "passengers")

# %%
 # change color and add value
x = sns.heatmap(flights, annot=True, fmt="d", cmap="YlGnBu")

# %% [markdown]
# 3D SCATTER PLOTS

# %%
mean = 3
number =50

x1 = np.random.normal(mean, 1, size=number)
y1 = np.random.normal(mean, 1, size=number)
z1 = np.random.normal(mean, 1, size=number)

# Plotting the 3D scatter
plt.figure(figsize=(6,5))
axes = plt.axes(projection='3d')

# %%
print(type(axes))
axes.scatter3D(x1, y1, z1)

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_zlabel('z')
plt.show()
# Out:
# <class 'matplotlib.axes._subplots.Axes3DSubplot'>

# %%
sns.set_style("darkgrid")

mean = 3
number =50

x1 = np.random.normal(mean, 1, size=number)
y1 = np.random.normal(mean, 1, size=number)
z1 = np.random.normal(mean, 1, size=number)

plt.figure(figsize=(6,5))
axes = plt.axes(projection='3d')
print(type(axes))
axes.scatter3D(x1, y1, z1)

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_zlabel('z')
plt.show()
# Out:
# <class 'matplotlib.axes._subplots.Axes3DSubplot'>

# %%
# Increasing the size of the scatter plots
sns.set_style("darkgrid")

mean = 3
number =50

x1 = np.random.normal(mean, 1, size=number)
y1 = np.random.normal(mean, 1, size=number)
z1 = np.random.normal(mean, 1, size=number)

plt.figure(figsize=(6,5))
axes = plt.axes(projection='3d')
print(type(axes))
axes.scatter3D(x1, y1, z1,s=100)

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_zlabel('z')
plt.show()
# Out:
# <class 'matplotlib.axes._subplots.Axes3DSubplot'>

# %%
# A spiral Plot
sns.set_style("whitegrid")

OMEGA = 2

Z1 = np.linspace(0, 10, 100)
X1 = np.cos(OMEGA*Z1)
Y1= np.sin(OMEGA*Z1)

plt.figure(figsize=(6,5))
axes = plt.axes(projection='3d')
axes.plot3D(X1,Y1,Z1)
# keeps padding between figure elements
plt.tight_layout()
plt.show()

# %%
# a 3D plot of a map

def finalfunc(x, y):
    return 50 - (x**2 + y**2)


sns.set_style('whitegrid')
N = 50

X_VAL = np.linspace(-5, 5, N)
Y_VAL = np.linspace(-5, 5, N)

X1, Y1 = np.meshgrid(X_VAL, Y_VAL)

Z1 =finalfunc(X1, Y1)

axes = plt.axes(projection='3d')
axes.plot_surface(X1, Y1, Z1)
plt.show()
